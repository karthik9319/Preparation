# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_frame = pd.read_csv("train.csv")
data_frame.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
data_frame.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000  ...
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000  ...
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000  ...
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     94.244521    46.660274      21.954110     3.409589    15.060959
# std     125.338794    66.256028      61.119149    29.317331    55.757415
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    25.000000       0.000000     0.000000     0.000000
# 75%     168.000000    68.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1460.000000   1460.000000  1460.000000  1460.000000    1460.000000
# mean      2.758904     43.489041     6.321918  2007.815753  180921.195890
# std      40.177307    496.123024     2.703626     1.328095   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     1452 non-null   object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %%
import matplotlib.pyplot as plt
data_frame.hist(bins=50, figsize=(30,30))
plt.show()

# %% [markdown]
# **Chechking for missing values**

# %%
#missing data
def missing_values(data_frame):
    total_values = data_frame.isna().sum().sort_values(ascending=False)
    percent = (data_frame.isna().sum()/data_frame.isna().count()).sort_values(ascending=False)
    missing_data = pd.concat([total_values, percent], axis=1, keys = ['Total', 'Percent'])
    return missing_data

# %%
missing_data = missing_values(data_frame)
missing_data.head(20)
# Out:
#               Total   Percent
# PoolQC         1453  0.995205
# MiscFeature    1406  0.963014
# Alley          1369  0.937671
# Fence          1179  0.807534
# FireplaceQu     690  0.472603
# LotFrontage     259  0.177397
# GarageCond       81  0.055479
# GarageType       81  0.055479
# GarageYrBlt      81  0.055479
# GarageFinish     81  0.055479
# GarageQual       81  0.055479
# BsmtExposure     38  0.026027
# BsmtFinType2     38  0.026027
# BsmtFinType1     37  0.025342
# BsmtCond         37  0.025342
# BsmtQual         37  0.025342
# MasVnrArea        8  0.005479
# MasVnrType        8  0.005479
# Electrical        1  0.000685
# Utilities         0  0.000000

# %%
data_frame.drop(['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu', 'Id' ], axis=1, inplace=True)

# %%
missing_data = missing_values(data_frame)
missing_data.head(15)
# Out:
#               Total   Percent
# LotFrontage     259  0.177397
# GarageType       81  0.055479
# GarageYrBlt      81  0.055479
# GarageCond       81  0.055479
# GarageQual       81  0.055479
# GarageFinish     81  0.055479
# BsmtExposure     38  0.026027
# BsmtFinType2     38  0.026027
# BsmtFinType1     37  0.025342
# BsmtCond         37  0.025342
# BsmtQual         37  0.025342
# MasVnrArea        8  0.005479
# MasVnrType        8  0.005479
# Electrical        1  0.000685
# Exterior1st       0  0.000000

# %%
corr_matrix = data_frame.corr()

# %%
corr_matrix['SalePrice'].sort_values(ascending=False)
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# GarageYrBlt      0.486362
# MasVnrArea       0.477493
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# LotFrontage      0.351799
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# MSSubClass      -0.084284
# EnclosedPorch   -0.128578
# KitchenAbvGr    -0.135907
# Name: SalePrice, dtype: float64

# %%
from pandas.plotting import scatter_matrix

attribs = ['OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea','TotalBsmtSF', '1stFlrSF']

scatter_matrix(data_frame[attribs], figsize=(20,20))

plt.show()

# %%
n_col = data_frame._get_numeric_data().columns
cat_cols = list(set(data_frame.columns) - set(n_col))
num_cols = list(set(data_frame.columns) - set(cat_cols))

print("Numerical Columns: ", num_cols)
print("Length of Numerical Columns: ", len(num_cols))
print('\n')
print("Categorical Columns: ", cat_cols)
print("Length of Categorical Columns: ", len(cat_cols))
# Out:
# Numerical Columns:  ['ScreenPorch', 'FullBath', 'BsmtFullBath', 'BsmtHalfBath', 'YearRemodAdd', 'BsmtFinSF2', 'Fireplaces', 'HalfBath', 'GrLivArea', '1stFlrSF', 'LowQualFinSF', 'BsmtFinSF1', 'TotRmsAbvGrd', 'OpenPorchSF', 'MSSubClass', 'WoodDeckSF', '2ndFlrSF', 'BsmtUnfSF', 'MasVnrArea', 'BedroomAbvGr', 'PoolArea', 'YrSold', 'SalePrice', 'MiscVal', 'MoSold', 'KitchenAbvGr', '3SsnPorch', 'EnclosedPorch', 'YearBuilt', 'GarageArea', 'OverallCond', 'LotFrontage', 'TotalBsmtSF', 'LotArea', 'GarageYrBlt', 'OverallQual', 'GarageCars']
# Length of Numerical Columns:  37
#
#
# Categorical Columns:  ['Exterior2nd', 'MasVnrType', 'KitchenQual', 'GarageFinish', 'Condition1', 'LandContour', 'MSZoning', 'GarageCond', 'Street', 'RoofStyle', 'BsmtCond', 'Exterior1st', 'LandSlope', 'BldgType', 'BsmtFinType1', 'Functional', 'PavedDrive', 'Foundation', 'LotConfig', 'CentralAir', 'ExterCond', 'Electrical', 'RoofMatl', 'SaleType', 'LotShape', 'Condition2', 'HouseStyle', 'GarageQual', 'GarageType', 'Neighborhood', 'SaleCondition', 'HeatingQC', 'ExterQual', 'BsmtFinType2', 'Utilities', 'Heating', 'BsmtExposure', 'BsmtQual']
# Length of Categorical Columns:  38

# %%
for i in range(len(num_cols)):
    if data_frame[num_cols[i]].isna().sum() > 0:
        print(num_cols[i],data_frame[num_cols[i]].isna().sum())
# Out:
# MasVnrArea 8
# LotFrontage 259
# GarageYrBlt 81

# %%
data_frame_num = data_frame._get_numeric_data()

data_frame_price = data_frame_num['SalePrice'].copy()

data_frame_num = data_frame_num.drop(['SalePrice'], axis=1)

# data_frame_price = data_frame_num['SalePrice'].copy()

# data_frame_num = data_frame_num.drop(['SalePrice'], axis=1)

# %%
data_frame_num.hist(bins=50, figsize=(20,20))

plt.show()

# %% [markdown]
# ### Numerical Cat Columns

# %%
data_frame_num['YrSold'].value_counts()
# Out:
# 2009    338
# 2007    329
# 2006    314
# 2008    304
# 2010    175
# Name: YrSold, dtype: int64

# %%
data_frame_num['Fireplaces'].value_counts()
# Out:
# 0    690
# 1    650
# 2    115
# 3      5
# Name: Fireplaces, dtype: int64

# %%
data_frame_num['HalfBath'].value_counts()
# Out:
# 0    913
# 1    535
# 2     12
# Name: HalfBath, dtype: int64

# %%
data_frame_num['GarageCars'].value_counts()
# Out:
# 2    824
# 1    369
# 3    181
# 0     81
# 4      5
# Name: GarageCars, dtype: int64

# %%
data_frame_num['FullBath'].value_counts()
# Out:
# 2    768
# 1    650
# 3     33
# 0      9
# Name: FullBath, dtype: int64

# %%
data_frame_num['TotRmsAbvGrd'].value_counts()
# Out:
# 6     402
# 7     329
# 5     275
# 8     187
# 4      97
# 9      75
# 10     47
# 11     18
# 3      17
# 12     11
# 14      1
# 2       1
# Name: TotRmsAbvGrd, dtype: int64

# %%
data_frame_num['BsmtFullBath'].value_counts()
# Out:
# 0    856
# 1    588
# 2     15
# 3      1
# Name: BsmtFullBath, dtype: int64

# %%
data_frame_num['BedroomAbvGr'].value_counts()
# Out:
# 3    804
# 2    358
# 4    213
# 1     50
# 5     21
# 6      7
# 0      6
# 8      1
# Name: BedroomAbvGr, dtype: int64

# %%
data_frame_num['OverallQual'].value_counts()
# Out:
# 5     397
# 6     374
# 7     319
# 8     168
# 4     116
# 9      43
# 3      20
# 10     18
# 2       3
# 1       2
# Name: OverallQual, dtype: int64

# %%
data_frame_num['OverallCond'].value_counts()
# Out:
# 5    821
# 6    252
# 7    205
# 8     72
# 4     57
# 3     25
# 9     22
# 2      5
# 1      1
# Name: OverallCond, dtype: int64

# %%
data_frame_num['MSSubClass'].value_counts()
# Out:
# 20     536
# 60     299
# 50     144
# 120     87
# 30      69
# 160     63
# 70      60
# 80      58
# 90      52
# 190     30
# 85      20
# 75      16
# 45      12
# 180     10
# 40       4
# Name: MSSubClass, dtype: int64

# %%
data_frame_num['MoSold'].value_counts()
# Out:
# 6     253
# 7     234
# 5     204
# 4     141
# 8     122
# 3     106
# 10     89
# 11     79
# 9      63
# 12     59
# 1      58
# 2      52
# Name: MoSold, dtype: int64

# %%
num_cat_cols = ['OverallCond', 'OverallQual', 'BedroomAbvGr',
                'BsmtFullBath', 'TotRmsAbvGrd', 'FullBath', 'GarageCars', 
               'HalfBath', 'Fireplaces']

# %% [markdown]
# ### Removing these columns as mostly they have 0 and data is overly left skewed

# %%
data_frame_num['LowQualFinSF'].value_counts()
# Out:
# 0      1434
# 80        3
# 360       2
# 528       1
# 53        1
# 120       1
# 144       1
# 156       1
# 205       1
# 232       1
# 234       1
# 371       1
# 572       1
# 390       1
# 392       1
# 397       1
# 420       1
# 473       1
# 479       1
# 481       1
# 513       1
# 514       1
# 515       1
# 384       1
# Name: LowQualFinSF, dtype: int64

# %%
data_frame_num['3SsnPorch'].value_counts()
# Out:
# 0      1436
# 168       3
# 216       2
# 144       2
# 180       2
# 245       1
# 238       1
# 290       1
# 196       1
# 182       1
# 407       1
# 304       1
# 162       1
# 153       1
# 320       1
# 140       1
# 130       1
# 96        1
# 23        1
# 508       1
# Name: 3SsnPorch, dtype: int64

# %%
data_frame_num['ScreenPorch'].value_counts()
# Out:
# 0      1344
# 192       6
# 224       5
# 120       5
# 189       4
#        ...
# 182       1
# 440       1
# 178       1
# 312       1
# 480       1
# Name: ScreenPorch, Length: 76, dtype: int64

# %%
data_frame_num['PoolArea'].value_counts()
# Out:
# 0      1453
# 738       1
# 648       1
# 576       1
# 555       1
# 519       1
# 512       1
# 480       1
# Name: PoolArea, dtype: int64

# %%
data_frame_num['MiscVal'].value_counts()
# Out:
# 0        1408
# 400        11
# 500         8
# 700         5
# 450         4
# 2000        4
# 600         4
# 1200        2
# 480         2
# 1150        1
# 800         1
# 15500       1
# 620         1
# 3500        1
# 560         1
# 2500        1
# 1300        1
# 1400        1
# 350         1
# 8300        1
# 54          1
# Name: MiscVal, dtype: int64

# %%
data_frame_num['EnclosedPorch'].value_counts()
# Out:
# 0      1252
# 112      15
# 96        6
# 120       5
# 144       5
#        ...
# 174       1
# 177       1
# 183       1
# 189       1
# 552       1
# Name: EnclosedPorch, Length: 120, dtype: int64

# %%
data_frame_num['KitchenAbvGr'].value_counts()
# Out:
# 1    1392
# 2      65
# 3       2
# 0       1
# Name: KitchenAbvGr, dtype: int64

# %%
data_frame_num['BsmtHalfBath'].value_counts()
# Out:
# 0    1378
# 1      80
# 2       2
# Name: BsmtHalfBath, dtype: int64

# %%
data_frame_num['BsmtFinSF2'].value_counts()
# Out:
# 0       1293
# 180        5
# 374        3
# 551        2
# 93         2
#         ...
# 532        1
# 544        1
# 546        1
# 547        1
# 1474       1
# Name: BsmtFinSF2, Length: 144, dtype: int64

# %%
data_frame_num['2ndFlrSF'].value_counts()
# Out:
# 0       829
# 728      10
# 504       9
# 672       8
# 546       8
#        ...
# 788       1
# 1116      1
# 1112      1
# 1111      1
# 1872      1
# Name: 2ndFlrSF, Length: 417, dtype: int64

# %%
data_frame_num.drop(['BsmtFinSF2', 'BsmtHalfBath', 'KitchenAbvGr', 
                     'EnclosedPorch', 'MiscVal', 'PoolArea', 
                     'ScreenPorch', '3SsnPorch', 'LowQualFinSF', 
                     '2ndFlrSF' ], axis=1, inplace=True)

# %%
data_frame_num.hist(bins=50, figsize=(30,20))

plt.show()

# %% [markdown]
# ### Adding new columns

# %%
remodel = data_frame_num['YearRemodAdd'] - data_frame_num['YearBuilt']

# %%
remodel
# Out:
# 0        0
# 1        0
# 2        1
# 3       55
# 4        0
#         ..
# 1455     1
# 1456    10
# 1457    65
# 1458    46
# 1459     0
# Length: 1460, dtype: int64

# %%
for i in range(len(remodel)):
    if remodel[i] != 0:
        remodel[i] = True
    else:
        remodel[i] = False

# %%
data_frame_num['RemodelStatus'] = remodel

# %%
data_frame_num['RemodelStatus'].value_counts()
# Out:
# False    764
# True     696
# Name: RemodelStatus, dtype: int64

# %%
houseage =  data_frame_num['YrSold'] - data_frame_num['YearRemodAdd']

# %%
houseage_months = []
for i in range(len(houseage)):
    x = houseage[i] * 12
    y = x + data_frame_num['MoSold'][i]
    houseage_months.append(y)

# %%
data_frame_num['HouseAge'] = houseage_months

# %%
data_frame_num.drop(['YearBuilt', 'YearRemodAdd', 'MoSold', 'YrSold'], axis=1, inplace=True)

# %%
data_frame_num.hist(bins=50, figsize=(20,20))

plt.show()

# %%
num_cat_cols
# Out:
# ['OverallCond',
#  'OverallQual',
#  'BedroomAbvGr',
#  'BsmtFullBath',
#  'TotRmsAbvGrd',
#  'FullBath',
#  'GarageCars',
#  'HalfBath',
#  'Fireplaces']

# %%
data_frame_pure_num = data_frame_num.copy()

# %%
data_frame_pure_num.drop(['OverallCond', 'OverallQual', 'BedroomAbvGr',
                         'BsmtFullBath', 'TotRmsAbvGrd', 'FullBath', 
                          'GarageCars', 'HalfBath', 'Fireplaces'], axis=1, inplace=True)

# %%
data_frame_pure_num.hist(bins=50, figsize=(20,20))

plt.show()

# %%
missing_values(data_frame_pure_num)
# Out:
#                Total   Percent
# LotFrontage      259  0.177397
# GarageYrBlt       81  0.055479
# MasVnrArea         8  0.005479
# HouseAge           0  0.000000
# RemodelStatus      0  0.000000
# OpenPorchSF        0  0.000000
# WoodDeckSF         0  0.000000
# GarageArea         0  0.000000
# GrLivArea          0  0.000000
# 1stFlrSF           0  0.000000
# TotalBsmtSF        0  0.000000
# BsmtUnfSF          0  0.000000
# BsmtFinSF1         0  0.000000
# LotArea            0  0.000000
# MSSubClass         0  0.000000

# %% [markdown]
# ## Imputing data to fill na values

# %%
from sklearn.impute import SimpleImputer

si = SimpleImputer(strategy = 'median')

x = si.fit_transform(data_frame_pure_num)

# %%
data_frame_pure_num_imputed = pd.DataFrame(x, columns= data_frame_pure_num.columns)

data_frame_pure_num_imputed.head()
# Out:
#    MSSubClass  LotFrontage  LotArea  MasVnrArea  BsmtFinSF1  BsmtUnfSF  \
# 0        60.0         65.0   8450.0       196.0       706.0      150.0
# 1        20.0         80.0   9600.0         0.0       978.0      284.0
# 2        60.0         68.0  11250.0       162.0       486.0      434.0
# 3        70.0         60.0   9550.0         0.0       216.0      540.0
# 4        60.0         84.0  14260.0       350.0       655.0      490.0
#
#    TotalBsmtSF  1stFlrSF  GrLivArea  GarageYrBlt  GarageArea  WoodDeckSF  \
# 0        856.0     856.0     1710.0       2003.0       548.0         0.0
# 1       1262.0    1262.0     1262.0       1976.0       460.0       298.0
# 2        920.0     920.0     1786.0       2001.0       608.0         0.0
# 3        756.0     961.0     1717.0       1998.0       642.0         0.0
# 4       1145.0    1145.0     2198.0       2000.0       836.0       192.0
#
#    OpenPorchSF  RemodelStatus  HouseAge
# 0         61.0            0.0      62.0
# 1          0.0            0.0     377.0
# 2         42.0            1.0      81.0
# 3         35.0            1.0     434.0
# 4         84.0            0.0     108.0

# %%
missing_values(data_frame_pure_num_imputed)
# Out:
#                Total  Percent
# HouseAge           0      0.0
# RemodelStatus      0      0.0
# OpenPorchSF        0      0.0
# WoodDeckSF         0      0.0
# GarageArea         0      0.0
# GarageYrBlt        0      0.0
# GrLivArea          0      0.0
# 1stFlrSF           0      0.0
# TotalBsmtSF        0      0.0
# BsmtUnfSF          0      0.0
# BsmtFinSF1         0      0.0
# MasVnrArea         0      0.0
# LotArea            0      0.0
# LotFrontage        0      0.0
# MSSubClass         0      0.0

# %% [markdown]
# ## Normalization of the numerical data

# %%
from sklearn.preprocessing import StandardScaler

standardscaler = StandardScaler()

data_frame_scaled = standardscaler.fit_transform(data_frame_pure_num_imputed)

# %%
df_scaled = pd.DataFrame(data_frame_scaled, columns = data_frame_pure_num.columns)

df_scaled.head()
# Out:
#    MSSubClass  LotFrontage   LotArea  MasVnrArea  BsmtFinSF1  BsmtUnfSF  \
# 0    0.073375    -0.220875 -0.207142    0.514104    0.575425  -0.944591
# 1   -0.872563     0.460320 -0.091886   -0.570750    1.171992  -0.641228
# 2    0.073375    -0.084636  0.073480    0.325915    0.092907  -0.301643
# 3    0.309859    -0.447940 -0.096897   -0.570750   -0.499274  -0.061670
# 4    0.073375     0.641972  0.375148    1.366489    0.463568  -0.174865
#
#    TotalBsmtSF  1stFlrSF  GrLivArea  GarageYrBlt  GarageArea  WoodDeckSF  \
# 0    -0.459303 -0.793434   0.370333     1.017598    0.351000   -0.752176
# 1     0.466465  0.257140  -0.482512    -0.107927   -0.060731    1.626195
# 2    -0.313369 -0.627826   0.515013     0.934226    0.631726   -0.752176
# 3    -0.687324 -0.521734   0.383659     0.809167    0.790804   -0.752176
# 4     0.199680 -0.045611   1.299326     0.892540    1.698485    0.780197
#
#    OpenPorchSF  RemodelStatus  HouseAge
# 0     0.216503      -0.954460 -0.887642
# 1    -0.704483      -0.954460  0.384909
# 2    -0.070361       1.047712 -0.810885
# 3    -0.176048       1.047712  0.615180
# 4     0.563760      -0.954460 -0.701809

# %%
df_scaled.hist(bins = 50, figsize=(20,20))

plt.show()

# %% [markdown]
# ### Trying MinMax Scaler

# %%
from sklearn.preprocessing import MinMaxScaler

minmax = MinMaxScaler()

df_scaled_minmax = minmax.fit_transform(data_frame_pure_num_imputed)

# %%
df_scaled_minmax = pd.DataFrame(df_scaled_minmax, columns= data_frame_pure_num.columns)

df_scaled_minmax.hist(bins=50, figsize = (20,20))

plt.show()

# %% [markdown]
# ## Analyzing Categorical Data

# %%
cat_cols
# Out:
# ['Exterior2nd',
#  'MasVnrType',
#  'KitchenQual',
#  'GarageFinish',
#  'Condition1',
#  'LandContour',
#  'MSZoning',
#  'GarageCond',
#  'Street',
#  'RoofStyle',
#  'BsmtCond',
#  'Exterior1st',
#  'LandSlope',
#  'BldgType',
#  'BsmtFinType1',
#  'Functional',
#  'PavedDrive',
#  'Foundation',
#  'LotConfig',
#  'CentralAir',
#  'ExterCond',
#  'Electrical',
#  'RoofMatl',
#  'SaleType',
#  'LotShape',
#  'Condition2',
#  'HouseStyle',
#  'GarageQual',
#  'GarageType',
#  'Neighborhood',
#  'SaleCondition',
#  'HeatingQC',
#  'ExterQual',
#  'BsmtFinType2',
#  'Utilities',
#  'Heating',
#  'BsmtExposure',
#  'BsmtQual']

# %%
len(cat_cols)
# Out:
# 38

# %%
num_cat_cols
# Out:
# ['OverallCond',
#  'OverallQual',
#  'BedroomAbvGr',
#  'BsmtFullBath',
#  'TotRmsAbvGrd',
#  'FullBath',
#  'GarageCars',
#  'HalfBath',
#  'Fireplaces']

# %%
len(num_cat_cols)
# Out:
# 9

# %%
cat_cols.extend(num_cat_cols)

# %%
print(cat_cols)
# Out:
# ['Exterior2nd', 'MasVnrType', 'KitchenQual', 'GarageFinish', 'Condition1', 'LandContour', 'MSZoning', 'GarageCond', 'Street', 'RoofStyle', 'BsmtCond', 'Exterior1st', 'LandSlope', 'BldgType', 'BsmtFinType1', 'Functional', 'PavedDrive', 'Foundation', 'LotConfig', 'CentralAir', 'ExterCond', 'Electrical', 'RoofMatl', 'SaleType', 'LotShape', 'Condition2', 'HouseStyle', 'GarageQual', 'GarageType', 'Neighborhood', 'SaleCondition', 'HeatingQC', 'ExterQual', 'BsmtFinType2', 'Utilities', 'Heating', 'BsmtExposure', 'BsmtQual', 'OverallCond', 'OverallQual', 'BedroomAbvGr', 'BsmtFullBath', 'TotRmsAbvGrd', 'FullBath', 'GarageCars', 'HalfBath', 'Fireplaces']

# %%
len(cat_cols)
# Out:
# 47

# %%
data_frame_cat = data_frame[cat_cols]

data_frame_cat.head()
# Out:
#   Exterior2nd MasVnrType KitchenQual GarageFinish Condition1 LandContour  \
# 0     VinylSd    BrkFace          Gd          RFn       Norm         Lvl
# 1     MetalSd       None          TA          RFn      Feedr         Lvl
# 2     VinylSd    BrkFace          Gd          RFn       Norm         Lvl
# 3     Wd Shng       None          Gd          Unf       Norm         Lvl
# 4     VinylSd    BrkFace          Gd          RFn       Norm         Lvl
#
#   MSZoning GarageCond Street RoofStyle  ... BsmtQual OverallCond OverallQual  \
# 0       RL         TA   Pave     Gable  ...       Gd           5           7
# 1       RL         TA   Pave     Gable  ...       Gd           8           6
# 2       RL         TA   Pave     Gable  ...       Gd           5           7
# 3       RL         TA   Pave     Gable  ...       TA           5           7
# 4       RL         TA   Pave     Gable  ...       Gd           5           8
#
#   BedroomAbvGr BsmtFullBath TotRmsAbvGrd FullBath GarageCars HalfBath  \
# 0            3            1            8        2          2        1
# 1            3            0            6        2          2        0
# 2            3            1            6        2          2        1
# 3            3            1            7        1          3        0
# 4            4            1            9        2          3        1
#
#   Fireplaces
# 0          0
# 1          1
# 2          1
# 3          1
# 4          1
#
# [5 rows x 47 columns]

# %%
missing_cat = missing_values(data_frame_cat)

missing_cat.head(11)
# Out:
#               Total   Percent
# BsmtExposure     38  0.026027
# BsmtFinType2     38  0.026027
# BsmtFinType1     37  0.025342
# BsmtQual         37  0.025342
# BsmtCond         37  0.025342
# MasVnrType        8  0.005479
# Electrical        1  0.000685
# Fireplaces        0  0.000000
# LandSlope         0  0.000000
# CentralAir        0  0.000000
# LotConfig         0  0.000000

# %% [markdown]
# For 'GarageFinish', 'GarageQual', 'GarageType', 'GarageCond' - Na means No Garrage
# Changing NAN values in these columns to NG No Garrage

# %%
data_frame_cat['GarageFinish'].fillna('NG', inplace=True)
data_frame_cat['GarageQual'].fillna('NG', inplace=True)
data_frame_cat['GarageType'].fillna('NG', inplace=True)
data_frame_cat['GarageCond'].fillna('NG', inplace=True)
# Out:
# /Users/karthik/anaconda3/lib/python3.7/site-packages/pandas/core/series.py:4523: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,

# %%
data_frame_cat['GarageFinish'].value_counts()
# Out:
# Unf    605
# RFn    422
# Fin    352
# NG      81
# Name: GarageFinish, dtype: int64

# %%
missing_cat = missing_values(data_frame_cat)

missing_cat.head(11)
# Out:
#               Total   Percent
# BsmtExposure     38  0.026027
# BsmtFinType2     38  0.026027
# BsmtFinType1     37  0.025342
# BsmtQual         37  0.025342
# BsmtCond         37  0.025342
# MasVnrType        8  0.005479
# Electrical        1  0.000685
# Fireplaces        0  0.000000
# LandSlope         0  0.000000
# CentralAir        0  0.000000
# LotConfig         0  0.000000

# %%
data_frame_cat['BsmtExposure'].value_counts()
# Out:
# No    953
# Av    221
# Gd    134
# Mn    114
# Name: BsmtExposure, dtype: int64

# %%
data_frame_cat['BsmtExposure'].fillna('NB', inplace=True)
data_frame_cat['BsmtFinType2'].fillna('NB', inplace=True)
data_frame_cat['BsmtFinType1'].fillna('NB', inplace=True)
data_frame_cat['BsmtQual'].fillna('NB', inplace=True)
data_frame_cat['BsmtCond'].fillna('NB', inplace=True)
# Out:
# /Users/karthik/anaconda3/lib/python3.7/site-packages/pandas/core/series.py:4523: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,

# %%
missing_cat = missing_values(data_frame_cat)

missing_cat.head(7)
# Out:
#              Total   Percent
# MasVnrType       8  0.005479
# Electrical       1  0.000685
# Exterior1st      0  0.000000
# ExterCond        0  0.000000
# CentralAir       0  0.000000
# LotConfig        0  0.000000
# Foundation       0  0.000000

# %%
data_frame_cat.dropna(inplace=True)
# Out:
# /Users/karthik/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
missing_cat = missing_values(data_frame_cat)

missing_cat.head(11)
# Out:
#               Total  Percent
# Fireplaces        0      0.0
# Exterior1st       0      0.0
# ExterCond         0      0.0
# CentralAir        0      0.0
# LotConfig         0      0.0
# Foundation        0      0.0
# PavedDrive        0      0.0
# Functional        0      0.0
# BsmtFinType1      0      0.0
# BldgType          0      0.0
# LandSlope         0      0.0

# %%
from sklearn.preprocessing import LabelBinarizer, LabelEncoder

lb = LabelBinarizer()

le = LabelEncoder()

# df_labeled = lb.fit_transform(data_frame_cat)

df_le = le.fit_transform(data_frame_cat)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-288-dd0086530606> in <module>
#       7 # df_labeled = lb.fit_transform(data_frame_cat)
#       8
# ----> 9 df_le = le.fit_transform(data_frame_cat)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_label.py in fit_transform(self, y)
#     253         y : array-like of shape [n_samples]
#     254         """
# --> 255         y = column_or_1d(y, warn=True)
#     256         self.classes_, y = _encode(y, encode=True)
#     257         return y
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in column_or_1d(y, warn)
#     845     raise ValueError(
#     846         "y should be a 1d array, "
# --> 847         "got an array of shape {} instead.".format(shape))
#     848
#     849
#
# ValueError: y should be a 1d array, got an array of shape (1451, 47) instead.

# %% [markdown]
# ## pipeline building

# %%
from sklearn.pipeline import Pipeline, FeatureUnion

num_attributes = list(df_scaled_minmax)
cat_attributes = list(data_frame_cat)
# Out:
# ['MSSubClass', 'LotFrontage', 'LotArea', 'MasVnrArea', 'BsmtFinSF1', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea', 'GarageYrBlt', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'RemodelStatus', 'HouseAge']
# ['Exterior2nd', 'MasVnrType', 'KitchenQual', 'GarageFinish', 'Condition1', 'LandContour', 'MSZoning', 'GarageCond', 'Street', 'RoofStyle', 'BsmtCond', 'Exterior1st', 'LandSlope', 'BldgType', 'BsmtFinType1', 'Functional', 'PavedDrive', 'Foundation', 'LotConfig', 'CentralAir', 'ExterCond', 'Electrical', 'RoofMatl', 'SaleType', 'LotShape', 'Condition2', 'HouseStyle', 'GarageQual', 'GarageType', 'Neighborhood', 'SaleCondition', 'HeatingQC', 'ExterQual', 'BsmtFinType2', 'Utilities', 'Heating', 'BsmtExposure', 'BsmtQual', 'OverallCond', 'OverallQual', 'BedroomAbvGr', 'BsmtFullBath', 'TotRmsAbvGrd', 'FullBath', 'GarageCars', 'HalfBath', 'Fireplaces']

# %%
#todo create model

# %%
data_frame_num['LotFrontage'].hist(bins=10)

print(data_frame_num['LotFrontage'].describe())
# Out:
# count    1201.000000
# mean       70.049958
# std        24.284752
# min        21.000000
# 25%        59.000000
# 50%        69.000000
# 75%        80.000000
# max       313.000000
# Name: LotFrontage, dtype: float64

# %%
data_frame_num['GarageYrBlt'].hist(bins=10)

print(data_frame_num['GarageYrBlt'].describe())
# Out:
# count    1379.000000
# mean     1978.506164
# std        24.689725
# min      1900.000000
# 25%      1961.000000
# 50%      1980.000000
# 75%      2002.000000
# max      2010.000000
# Name: GarageYrBlt, dtype: float64

# %%
data_frame_num['MasVnrArea'].hist(bins=10)

print(data_frame_num['MasVnrArea'].describe())
# Out:
# count    1452.000000
# mean      103.685262
# std       181.066207
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       166.000000
# max      1600.000000
# Name: MasVnrArea, dtype: float64

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy = 'median')

# %%
imputer.fit(data_frame_num['LotFrontage'].values.reshape(-1, 1))
# Out:
# SimpleImputer(strategy='median')

# %%
data_frame_num['MedianLotFrontage'] = imputer.transform(data_frame_num['LotFrontage'].values.reshape(-1, 1))

# %%
data_frame_num['MedianLotFrontage'].describe()
# Out:
# count    1460.000000
# mean       69.863699
# std        22.027677
# min        21.000000
# 25%        60.000000
# 50%        69.000000
# 75%        79.000000
# max       313.000000
# Name: MedianLotFrontage, dtype: float64

# %%
data_frame_num['LotFrontage'].describe()
# Out:
# count    1201.000000
# mean       70.049958
# std        24.284752
# min        21.000000
# 25%        59.000000
# 50%        69.000000
# 75%        80.000000
# max       313.000000
# Name: LotFrontage, dtype: float64

# %%
data_frame_num['MedianLotFrontage'].hist(bins = 10)

# %%
# data_frame_num.boxplot(figsize = (30,30))

# %%
data_frame_num['OverallQual'].groupby('SalePrice').hist()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-71-2a3b9dbdfbf7> in <module>
# ----> 1 data_frame_num['OverallQual'].groupby('SalePrice').hist()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    1731             squeeze=squeeze,
#    1732             observed=observed,
# -> 1733             dropna=dropna,
#    1734         )
#    1735
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     531                 observed=observed,
#     532                 mutated=self.mutated,
# --> 533                 dropna=self.dropna,
#     534             )
#     535
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     779                 in_axis, name, level, gpr = False, None, gpr, None
#     780             else:
# --> 781                 raise KeyError(gpr)
#     782         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     783             # Add key to exclusions
#
# KeyError: 'SalePrice'

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(data_frame_num, alpha=0.2, figsize=(300,200), diagonal='kde')
plt.show()

# %% [markdown]
# ## Base Model

# %%
imputer.fit(data_frame_num)

# %%
imputer.statistics_

# %%
num_x = imputer.transform(data_frame_num)

# %%
num_train_x = pd.DataFrame(num_x, columns = data_frame_num.columns)

num_train_x.head()

# %%
num_train_x.isna().sum()

# %%
num_
