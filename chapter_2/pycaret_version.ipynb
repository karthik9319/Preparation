# %%
import pycaret

# %%
data = pd.read_csv("datasets/housing/housing.csv")
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
data.shape
# Out:
# (20640, 10)

# %%
data = data.sample(frac=0.9, random_state=42).reset_index(drop=True)
data_unseen = data.drop(data.index).reset_index(drop=True)

print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (18576, 10)
# Unseen Data For Predictions: (0, 10)

# %%
from pycaret.regression import *

# %%
exp_reg01 = setup(data = data, target='median_house_value', session_id=123)
# Out:
#
# Setup Succesfully Completed.
# <style  type="text/css" >
# #T_f5bf9726_0711_11eb_8d7e_acde48001122row4_col1{
#             background-color:  yellow;
#         }</style><table id="T_f5bf9726_0711_11eb_8d7e_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f5bf9726_0711_11eb_8d7e_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f5bf9726_0711_11eb_8d7e_acde48001122row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_f5bf9726_0711_11eb_8d7e_acde48001122row0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_f5bf9726_0711_11eb_8d7e_acde48001122level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %%
compare_models()
# Out:
# IntProgress(value=0, description='Processing: ', max=251)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                   19:22:21
# Status     . . . . . . . . . . . . . . . . . .       Fitting Fold 1 of 10
# Estimator  . . . . . . . . . . . . . . . . . .  Extreme Gradient Boosting
# ETC        . . . . . . . . . . . . . . . . . .            Calculating ETC
#                            Model          MAE           MSE         RMSE  \
# 0                  Random Forest   32914.2109  2.559843e+09   50567.4709
# 1          Extra Trees Regressor   35263.5418  2.815911e+09   53053.8143
# 2    Gradient Boosting Regressor   38631.5192  3.103940e+09   55704.1723
# 3               Ridge Regression   50222.9182  4.788196e+09   69189.5043
# 4   Lasso Least Angle Regression   50208.8282  4.788561e+09   69192.3568
# 5                 Bayesian Ridge   50228.7726  4.788169e+09   69189.3234
# 6              Linear Regression   50219.4353  4.788195e+09   69189.4924
# ...
